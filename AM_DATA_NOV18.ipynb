# %%
import pandas as pd

# %%
amd_data=pd.read_csv("/home/estudiantes/Downloads/adm_data.csv")

# %%
amd_data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
amd_data.keys()
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
amd_data.drop("Serial No.", axis=1)
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
amd_data.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
amd_data.sample(10)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 309         310        308          110                  4  3.5   3.0  8.60
# 274         275        315          100                  1  2.0   2.5  7.95
# 222         223        324          113                  4  4.5   4.0  8.79
# 70           71        332          118                  5  5.0   5.0  9.64
# 107         108        338          117                  4  3.5   4.5  9.46
# 312         313        311          107                  4  4.5   4.5  9.00
# 128         129        326          112                  3  3.5   3.0  9.10
# 310         311        320          104                  3  3.0   3.5  8.74
# 380         381        322          104                  3  3.5   4.0  8.84
# 84           85        340          115                  5  4.5   4.5  9.45
#
#      Research  Chance of Admit
# 309         0              0.70
# 274         0              0.58
# 222         0              0.76
# ...

# %%
amd_data.shape
# Out:
# (400, 9)

# %%
amd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
amd_data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
Uranking=amd_data["University Rating"].unique()
Urating.sort()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [26], line 2
#       1 Uranking=amd_data["University Rating"].unique()
# ----> 2 Urating.sort()
#
# NameError: name 'Urating' is not defined

# %%
Urating

# %%
array([1,2,3,4,5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 array([1,2,3,4,5])
#
# NameError: name 'array' is not defined

# %%
rating1= amd_data[amd_data["University Rating"]==1]

# %%
rating1.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating        SOP  \
# count   26.000000   26.000000    26.000000               26.0  26.000000
# mean   233.807692  303.153846    99.076923                1.0   1.884615
# std    129.663879    7.918042     3.856663                0.0   0.739022
# min      9.000000  290.000000    92.000000                1.0   1.000000
# 25%    145.000000  298.000000    98.000000                1.0   1.500000
# 50%    273.500000  300.500000    99.000000                1.0   1.750000
# 75%    348.750000  311.000000   100.000000                1.0   2.000000
# max    380.000000  318.000000   109.000000                1.0   3.500000
#
#             LOR        CGPA   Research  Chance of Admit
# count  26.000000  26.000000  26.000000         26.000000
# mean    2.211538   7.745769   0.192308          0.548077
# std     0.602878   0.450992   0.401918          0.089220
# min     1.000000   6.800000   0.000000          0.360000
# ...

# %%
rating1.mean()
# Out:
# Serial No.           233.807692
# GRE Score            303.153846
# TOEFL Score           99.076923
# University Rating      1.000000
# SOP                    1.884615
# LOR                    2.211538
# CGPA                   7.745769
# Research               0.192308
# Chance of Admit        0.548077
# dtype: float64

# %%
for x in range(1,5):
    rating= amd_data[amd_data["University Rating"]==x]
print(f"Para Universidades con rating {x}")
print(rating.mean())
# Out:
# Para Universidades con rating 4
# Serial No.           199.594595
# GRE Score            324.824324
# TOEFL Score          111.824324
# University Rating      4.000000
# SOP                    4.108108
# LOR                    4.006757
# CGPA                   9.021622
# Research               0.797297
# Chance of Admit        0.818108
# dtype: float64

# %%
means_by_rating=amd_data.groupby(["University Rating"]).mean()
means_by_rating
# Out:
#                    Serial No.   GRE Score  TOEFL Score       SOP      LOR   \
# University Rating
# 1                  233.807692  303.153846    99.076923  1.884615  2.211538
# 2                  214.813084  309.177570   103.523364  2.705607  2.925234
# 3                  204.165414  315.954887   106.887218  3.364662  3.402256
# 4                  199.594595  324.824324   111.824324  4.108108  4.006757
# 5                  153.533333  328.333333   113.666667  4.500000  4.358333
#
#                        CGPA  Research  Chance of Admit
# University Rating
# 1                  7.745769  0.192308          0.548077
# 2                  8.183738  0.299065          0.625981
# 3                  8.552256  0.533835          0.711880
# 4                  9.021622  0.797297          0.818108
# 5                  9.291167  0.866667          0.888167

# %%
# Para archivo de latex 
print(means_by_rating.to_latex(index=True))
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# {} &  Serial No. &   GRE Score &  TOEFL Score &       SOP &      LOR  &      CGPA &  Research &  Chance of Admit  \\
# University Rating &             &             &              &           &           &           &           &                   \\
# \midrule
# 1                 &  233.807692 &  303.153846 &    99.076923 &  1.884615 &  2.211538 &  7.745769 &  0.192308 &          0.548077 \\
# 2                 &  214.813084 &  309.177570 &   103.523364 &  2.705607 &  2.925234 &  8.183738 &  0.299065 &          0.625981 \\
# 3                 &  204.165414 &  315.954887 &   106.887218 &  3.364662 &  3.402256 &  8.552256 &  0.533835 &          0.711880 \\
# 4                 &  199.594595 &  324.824324 &   111.824324 &  4.108108 &  4.006757 &  9.021622 &  0.797297 &          0.818108 \\
# 5                 &  153.533333 &  328.333333 &   113.666667 &  4.500000 &  4.358333 &  9.291167 &  0.866667 &          0.888167 \\
# \bottomrule
# ...

# %%
#Segunda instrucción para convertir a látex
print(means_by_rating.style.to_latex())
# Out:
# \begin{tabular}{lrrrrrrrr}
#  & Serial No. & GRE Score & TOEFL Score & SOP & LOR  & CGPA & Research & Chance of Admit  \\
# University Rating &  &  &  &  &  &  &  &  \\
# 1 & 233.807692 & 303.153846 & 99.076923 & 1.884615 & 2.211538 & 7.745769 & 0.192308 & 0.548077 \\
# 2 & 214.813084 & 309.177570 & 103.523364 & 2.705607 & 2.925234 & 8.183738 & 0.299065 & 0.625981 \\
# 3 & 204.165414 & 315.954887 & 106.887218 & 3.364662 & 3.402256 & 8.552256 & 0.533835 & 0.711880 \\
# 4 & 199.594595 & 324.824324 & 111.824324 & 4.108108 & 4.006757 & 9.021622 & 0.797297 & 0.818108 \\
# 5 & 153.533333 & 328.333333 & 113.666667 & 4.500000 & 4.358333 & 9.291167 & 0.866667 & 0.888167 \\
# \end{tabular}

# %%
import matplotlib.pyplot as plt

# %%
amd_data["GRE norm Score"]=amd_data["GRE Score"]/340
amd_data["TOEFL norm Score"]=amd_data["TOEFL Score"]/120

# %%
amd_data["GRE norm Score"].hist(alpha=0.5, label="GRE")
amd_data["TOEFL norm Score"].hist(alpha=0.5, label="TOEFL")
plt.xlabel("Normalized Score")
plt.ylabel("No. Alumnos")

plt.legend()
plt.savefig("/home/estudiantes/Valentina/Histograma.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [56], line 7
#       4 plt.ylabel("No. Alumnos")
#       6 plt.legend()
# ----> 7 plt.savefig("/home/estudiantes/Valentina/Histograma.pdf")
#
# File ~/miniconda3/envs/higi22/lib/python3.10/site-packages/matplotlib/pyplot.py:977, in savefig(*args, **kwargs)
#     974 @_copy_docstring_and_deprecators(Figure.savefig)
#     975 def savefig(*args, **kwargs):
#     976     fig = gcf()
# --> 977     res = fig.savefig(*args, **kwargs)
#     978     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     979     return res
#
# File ~/miniconda3/envs/higi22/lib/python3.10/site-packages/matplotlib/figure.py:3058, in Figure.savefig(self, fname, transparent, **kwargs)
#    3054     for ax in self.axes:
#    3055         stack.enter_context(
# ...
